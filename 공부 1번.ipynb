# %%
import csv
f = open('gender.csv')
data = csv.reader(f)
m = []
f = []
name = input('찾고 싶은 지역의 이름을 알려주세요 : ')
# 제주특별자치도 검색 -> gender.csv 파일에 제주특별자치도라는 데이터가 여러 개 존재해서 오류

for row in data :
    if name in row[0] :
        for i in row[3:104] :
            m.append(-int(i))
        for i in row[106:] :
            f.append(int(i))
        break # 가장 처음에 나오는 제주특별자치도 데이터를 찾고 반복을 멈춤

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi=300)
plt.rc('font', family = 'Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.title(name + ' 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label = '남성')
plt.barh(range(101), f, label = '여성')
plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 강릉

# %%
print(len(m), len(f)) 
# 반복문에 break 처리를 해주지 않을시 제주특별자치도가 포함된 모든 데이터를 가져와서 원하는 데이터를 사용하기 어려움
# Out:
# 101 101

# %%
import matplotlib.pyplot as plt
plt.pie([10,20]) # pie() 파이그래프, 3시부터 반시계 방향 
plt.show()

# %%
import matplotlib.pyplot as plt
size = [2441, 2312, 1031, 1233]
plt.axis('equal') # 원 찌그러짐 방지
plt.pie(size)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun Gothic')
size = [2441, 2312, 1031, 1233]
label = ['A형','B형','AB형','O형']
plt.axis('equal')
plt.pie(size, labels = label, autopct = '%.1f%%') # 비율 및 범례 추가, '%.1f%%' 소수점 한자리까지 표현
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun Gothic')
size = [2441, 2312, 1031, 1233]
label = ['A형', 'B형', 'AB형', 'O형']
color = ['darkmagenta', 'deeppink', 'hotpink', 'pink']
plt.axis('equal')
plt.pie(size, labels = label, autopct = '%.1f%%', explode = (0,0,0.1,0), colors = color) # explode 돌출효과
plt.legend()
plt.show()

# %%
import csv
f = open('gender.csv')
data = csv.reader(f)
size = []
name = input('찾고 싶은 지역의 이름을 알려주세요 : ')

for row in data :
    if name in row[0] :
        m = 0
        f = 0
        for i in range(101) : # 0~100까지 반복
            m += int(row[i+3]) # 3~103번열의 데이터. 남성 0세~100세
            f += int(row[i+106]) # 106~206번열의 데이터. 여성 0세~100세
            # 리스트가 아닌 변수에 값을 누적해서 저장
            # 0세부터 100세까지의 남성의 총 인구, 여성의 총 인구를 알 수 있음
        break
size.append(m)
size.append(f) # size[0] 남성의 총 인구, size[1] 여성의 총 인구

import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun Gothic')
color = ['crimson', 'darkcyan']
plt.axis('equal')
plt.pie(size, labels = ['남','여'], autopct = '%.1f%%', colors = color, startangle = 90) 
# startangle = 90 기존 3시 기준에서 반시계 방향으로 90도 회전해서 기준점을 잡음
plt.title(name + ' 지역의 남녀 성별 비율')
plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 강릉

# %%
import csv
f = open('gender.csv')
data = csv.reader(f)
m=[]
f=[]
name = input('궁금한 동네를 입력하세요 : ')

for row in data :
    if name in row[0] :
        for i in range(3, 104) :
            m.append(int(row[i]))
            f.append(int(row[i+103]))
        break
        
import matplotlib.pyplot as plt
plt.plot(m, label = 'Male')
plt.plot(f, label = 'Female')
plt.legend()
plt.show()
# 각 인구수별 수치데이터를 비교하기에는 파이그래프보다 꺾은선그래프나 바그래프가 유용하다
# Out:
# 궁금한 동네를 입력하세요 : 강릉

# %%
import csv
f = open('gender.csv')
data = csv.reader(f)
result = []
name = input('찾고 싶은 동네를 입력하세요 : ')

for row in data :
    if name in row[0] :
        for i in range(3, 104) :
            result.append(int(row[i]) - int(row[i+103])) # 각 연령대별 (남성 인구수 - 여성 인구수) 계산해서 result에 저장 
        break
        
import matplotlib.pyplot as plt
plt.bar(range(101), result) # result 값이 양수면 남자 인구수가 많고, 값이 음수면 여성 인구수가 많다
plt.show()
# Out:
# 찾고 싶은 동네를 입력하세요 : 강릉

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.scatter([1,2,3,4], [10,30,20,40]) # scatter 산점도그래프. 데이터간의 관계를 파악하거나, 밀집도 파악에 유용하다.
# 산점도 그래프의 점 크기를 조절하면 버블그래프라고 한다.
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.scatter([1,2,3,4], [10,30,20,40], s = [100,200,250,300]) # scatter 내의 s = 점 사이즈 설정 c = 컬러 설정
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.scatter([1,2,3,4], [10,30,20,40], s = [30, 60, 90, 120], c = ['red', 'blue', 'green', 'gold']) 
# scatter 내의 s = 점 사이즈 설정 c = 컬러 설정  
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.scatter([1,2,3,4], [10,30,20,40], s = [30,60,90,120], c = range(4)) 
# 컬러의 이름이 아니라, 컬러의 개수를 저장. 동일하지 않은 랜덤 색으로 자동설정
plt.colorbar() # 점 색상에 맞는 컬러바가 화면에 표시됨
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.scatter([1,2,3,4], [10,30,20,40], s = [30,60,90,120], c = range(4), cmap = 'CMRmap') # cmap 이미 저장된 색 데이터를 불러옴
# matplotlib 라이브러리에서 제공하는 컬러맵 : flag, prism, ocean, brg, jet, CMRmap 등등
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import random
x = []
y = []
size = []

for i in range(100) :
    x.append(random.randint(50,100))
    y.append(random.randint(50,100))
    size.append(random.randint(10,200))

plt.style.use('ggplot')
plt.scatter(x, y, s = size, c = size, cmap = 'CMRmap', alpha = 0.3) 
# c에 size리스트를 넣으면 해당하는 색상,갯수 표현
# alpha 점 투명도 조절 0~1사이 표현. 기본값 1. 0에 가까울수록 투명해짐
plt.colorbar()
plt.show()

# %%
import csv
f = open('gender.csv')
data = csv.reader(f)
m = []
f = []
name =input('궁금한 동네를 입력하세요 : ')

for row in data :
    if name in row[0] :
        for i in range(3, 104) :
            m.append(int(row[i]))
            f.append(int(row[i+103]))
        break
    
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.scatter(m, f, c = range(101), cmap = 'jet', alpha = 0.5)
plt.plot(range(max(m)), range(max(m)), 'g')
# 추세선 = 가이드가 되는 선, x = y 형태로 선을 그어 차이를 표현
# max(m) = 6900이라 치고, 0부터 0.1 단위로 6900까지 x축도 0~6900, y축도 0~6900인 선을 그림
plt.colorbar()
plt.show()
# Out:
# 궁금한 동네를 입력하세요 : 강릉

# %%
import csv
import math
f = open('gender.csv')
data = csv.reader(f)
m = []
f = []
size = []
name = input('굼긍한 동네를 입력하세요 : ')

for row in data :
    if name in row[0] :
        for i in range(3, 104) :
            m.append(int(row[i]))
            f.append(int(row[i+103]))
            size.append(math.sqrt(int(row[i]) + int(row[i+103]))) # math.sqrt 제곱근. 총인구수의 제곱근을 구함
        break
    
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rc('font', family = 'Malgun Gothic')
plt.figure(figsize = (10,5), dpi = 300)
plt.title(name + ' 지역의 성별 인구 그래프')
plt.scatter(m, f, s = size, c = range(101), cmap = 'CMRmap', alpha = 0.5) # 총 인구수가 많을수록 점 크기가 커짐
plt.colorbar()
plt.plot(range(max(m)), range(max(m)), 'g')
plt.xlabel('남성 인구수')
plt.ylabel('여성 인구수')
plt.show()
# Out:
# 굼긍한 동네를 입력하세요 : 강릉
